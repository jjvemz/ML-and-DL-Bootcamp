# %% [markdown]
# # Arreglos

# %%
import pandas as pd
import numpy as np

# %%
sample_array= np.array([1,2,3,4])
sample_array
# Out:
# array([1, 2, 3, 4])

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
zeros = np.zeros((2,3), dtype= int)
zeros
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
zeros.dtype
# Out:
# dtype('int64')

# %%
random_array= np.random.randint(1,10, size=(4,2))
random_array
# Out:
# array([[5, 3],
#        [2, 2],
#        [5, 1],
#        [7, 5]], dtype=int32)

# %%
random_array.size
# Out:
# 8

# %% [markdown]
# # Random seeding

# %%
random_array2= np_random.randint(10, size=(5,3))
